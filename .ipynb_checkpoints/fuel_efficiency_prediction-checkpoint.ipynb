# %%
import sys
import sklearn
import tensorflow as tf
import numpy as np

print("Python Version:", sys.version)
print("Scikit-learn Version:", sklearn.__version__)
print("TensorFlow Version:", tf.__version__)
print("NumPy Version:", np.__version__)
# Out:
# 2026-02-27 16:13:33.665485: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-27 16:13:36.819104: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-27 16:13:36.819339: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-27 16:13:38.211163: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-27 16:13:43.784187: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import load_model
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
import sklearn
import numpy as np
from sklearn.metrics import (mean_squared_error, mean_absolute_error,r2_score)
import pickle

# %%
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')

if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("GPU is available")
else:
    print("GPU not available, using CPU")
# Out:
# GPU not available, using CPU

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
df = pd.read_csv("fuel_mpg.csv", na_values='?')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# <h1 style="color:brown">Exploratory Data Analysis</h1>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
df['car name'].unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'plymouth satellite custom', 'ford torino 500', 'amc matador',
#        'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
#        'pontiac firebird', 'ford mustang', 'mercury capri 2000',
# ...

# %%
unique_car_names_count=df['car name'].unique()
print("unique number of cars are : ",len(unique_car_names_count))
# Out:
# unique number of cars are :  301

# %% [markdown]
# now  Drop Car Name

# %%
df.drop(['car name'],axis=1,inplace=True)

# %% [markdown]
# <h1 style="color:brown">Splitting in Train and Test</h1>

# %%
X=df.drop("mpg",axis=1)

# %%
X
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
Y=df['mpg']

# %%
Y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=101)

# %%
X_train.head()
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 274          5         131.0       103.0    2830          15.9          78
# 157          8         350.0       145.0    4440          14.0          75
# 173          4         119.0        97.0    2545          17.0          75
# 357          4         119.0       100.0    2615          14.8          81
# 263          6         231.0       165.0    3445          13.4          78
#
#      origin
# 274       2
# 157       1
# 173       3
# 357       3
# 263       1

# %%
X_test.head()
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 39           8         400.0       175.0    4464          11.5          71
# 285          8         305.0       130.0    3840          15.4          79
# 164          6         231.0       110.0    3039          15.0          75
# 220          4          85.0        70.0    1945          16.8          77
# 163          6         225.0        95.0    3785          19.0          75
#
#      origin
# 39        1
# 285       1
# 164       1
# 220       3
# 163       1

# %%
Y_train.head()
# Out:
# 274    20.3
# 157    15.0
# 173    24.0
# 357    32.9
# 263    17.7
# Name: mpg, dtype: float64

# %%
Y_test.head()
# Out:
# 39     14.0
# 285    17.0
# 164    21.0
# 220    33.5
# 163    18.0
# Name: mpg, dtype: float64

# %% [markdown]
# importing standard scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train_std=sc.fit_transform(X_train)
X_test_std=sc.transform(X_test)

# %%
X_train_std
# Out:
# array([[-0.24893345, -0.57765698, -0.02197412, ...,  0.11961844,
#          0.54658592,  0.49337407],
#        [ 1.52188861,  1.52787598,  1.06400983, ..., -0.55787761,
#         -0.26938257, -0.74203461],
#        [-0.83920747, -0.69302865, -0.17711468, ...,  0.51185299,
#         -0.26938257,  1.72878276],
#        ...,
#        [ 0.34134057, -0.17385614,  0.15902321, ..., -1.05708522,
#          1.36255441, -0.74203461],
#        [ 1.52188861,  1.43173292,  1.45186124, ..., -2.6973388 ,
#         -1.62933005, -0.74203461],
#        [-0.83920747, -0.79878601, -0.74596341, ...,  0.44053762,
#          1.36255441,  1.72878276]])

# %%
X_test_std
# Out:
# array([[ 1.52188861e+00,  2.00859127e+00,  1.83971265e+00,
#          1.78911930e+00, -1.44931977e+00, -1.35734055e+00,
#         -7.42034609e-01],
#        [ 1.52188861e+00,  1.09523222e+00,  6.76158422e-01,
#          1.04842530e+00, -5.86699954e-02,  8.18575415e-01,
#         -7.42034609e-01],
#        [ 3.41340567e-01,  3.83773597e-01,  1.59023209e-01,
#          9.76305932e-02, -2.01300742e-01, -2.69382568e-01,
#         -7.42034609e-01],
#        [-8.39207472e-01, -1.01991504e+00, -8.75247218e-01,
#         -1.20095793e+00,  4.40537616e-01,  2.74596424e-01,
#          1.72878276e+00],
#        [ 3.41340567e-01,  3.26087762e-01, -2.28828201e-01,
#          9.83139770e-01,  1.22500672e+00, -2.69382568e-01,
#         -7.42034609e-01],
#        [ 3.41340567e-01,  5.66445406e-01, -6.68393133e-01,
#          7.32680740e-01,  1.93816045e+00,  2.60692807e-03,
#         -7.42034609e-01],
#        [-8.39207472e-01, -1.14490101e+00, -9.01103979e-01,
# ...

# %% [markdown]
# <h1 style="color:brown">SC transform</h1>

# %%
pickle.dump(sc, open('models/scaler.pkl', 'wb'))

# %%
X_train.keys()
# Out:
# Index(['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration',
#        'model year', 'origin'],
#       dtype='object')

# %%
len(X_train.keys())
# Out:
# 7

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

def create_model():
    # Initialising the ANN
    model = Sequential()
    # Adding the input layer and the first hidden layer
    model.add(Dense(64, activation='relu', input_shape=[7]))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    # Adding the output layer

    # Compiling the ANN
    model.compile(
        loss='mean_squared_error',
        optimizer='Adam',
        metrics=['mean_absolute_error', 'mean_squared_error']
    )
    
    return model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                512
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 1)                 65
#
# ...
# Total params: 13057 (51.00 KB)
# Trainable params: 13057 (51.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fitting the ANN to the Training set
model_100_epochs = create_model()

history_100_epochs = model_100_epochs.fit(
    X_train_std,
    Y_train,
    batch_size=100,
    epochs=100
)

model_100_epochs.save("models/model_100_epochs.keras")
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 12ms/step - loss: 614.1431 - mean_absolute_error: 23.4773 - mean_squared_error: 614.1431
# Epoch 2/100
# 4/4 [==============================] - 0s 8ms/step - loss: 598.7359 - mean_absolute_error: 23.1287 - mean_squared_error: 598.7359
# Epoch 3/100
# 4/4 [==============================] - 0s 8ms/step - loss: 579.3071 - mean_absolute_error: 22.6742 - mean_squared_error: 579.3071
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 553.0144 - mean_absolute_error: 22.0591 - mean_squared_error: 553.0144
# Epoch 5/100
# 4/4 [==============================] - 0s 8ms/step - loss: 516.1743 - mean_absolute_error: 21.1463 - mean_squared_error: 516.1743
# Epoch 6/100
# 4/4 [==============================] - 0s 12ms/step - loss: 463.4453 - mean_absolute_error: 19.8135 - mean_squared_error: 463.4453
# Epoch 7/100
# ...

# %%
X_test_std
# Out:
# array([[ 1.52188861e+00,  2.00859127e+00,  1.83971265e+00,
#          1.78911930e+00, -1.44931977e+00, -1.35734055e+00,
#         -7.42034609e-01],
#        [ 1.52188861e+00,  1.09523222e+00,  6.76158422e-01,
#          1.04842530e+00, -5.86699954e-02,  8.18575415e-01,
#         -7.42034609e-01],
#        [ 3.41340567e-01,  3.83773597e-01,  1.59023209e-01,
#          9.76305932e-02, -2.01300742e-01, -2.69382568e-01,
#         -7.42034609e-01],
#        [-8.39207472e-01, -1.01991504e+00, -8.75247218e-01,
#         -1.20095793e+00,  4.40537616e-01,  2.74596424e-01,
#          1.72878276e+00],
#        [ 3.41340567e-01,  3.26087762e-01, -2.28828201e-01,
#          9.83139770e-01,  1.22500672e+00, -2.69382568e-01,
#         -7.42034609e-01],
#        [ 3.41340567e-01,  5.66445406e-01, -6.68393133e-01,
#          7.32680740e-01,  1.93816045e+00,  2.60692807e-03,
#         -7.42034609e-01],
#        [-8.39207472e-01, -1.14490101e+00, -9.01103979e-01,
# ...

# %%
prediction=model.predict(X_test_std)
# Out:
# 3/3 [==============================] - 0s 6ms/step

# %%
prediction
# Out:
# array([[ 0.01481214],
#        [-0.00612848],
#        [-0.02725887],
#        [-0.0007924 ],
#        [ 0.01142176],
#        [ 0.02523479],
#        [-0.06002849],
#        [ 0.05445278],
#        [ 0.05592825],
#        [-0.00691798],
#        [-0.00478353],
#        [-0.05911354],
#        [-0.09209413],
#        [-0.06176711],
#        [-0.04866496],
#        [ 0.0445315 ],
#        [-0.04196888],
#        [-0.0693488 ],
#        [-0.01839724],
#        [-0.02063398],
#        [-0.04295422],
#        [-0.01028062],
#        [-0.06678504],
#        [ 0.00206431],
#        [ 0.01049345],
#        [-0.01561652],
#        [ 0.05524322],
#        [ 0.02890056],
#        [ 0.07205675],
#        [ 0.0118559 ],
#        [-0.02139487],
#        [-0.01099155],
#        [ 0.08466069],
#        [-0.06611995],
#        [ 0.03374343],
#        [ 0.00156933],
#        [-0.02198853],
#        [ 0.06102611],
#        [-0.0334979 ],
#        [-0.04315078],
#        [ 0.01740192],
# ...

# %%
rmse=np.sqrt(mean_squared_error(Y_test,prediction))

print('RMSE: ',rmse)

print('R_square:', r2_score(Y_test,prediction))
# Out:
# RMSE:  24.044606854361646
# R_square: -9.607620407930371

# %% [markdown]
# Lets predict for a  car

# %%
list1=[[4,97,100,5000,14.5,70,3]]
list1=sc.transform(list1)
list1
# Out:
# /home/rguktvalley/anaconda3/envs/fuel_project/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.83920747, -0.90454337, -0.0995444 ,  2.42535646, -0.37958917,
#         -1.62933005,  1.72878276]])

# %%
prediction1 = model_100_epochs.predict(list1)
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
prediction1
# Out:
# array([[28.102598]], dtype=float32)

# %%
list2=[[8,307,130,3504,12,70,1]]
list2=sc.transform(list2)
list2
# Out:
# /home/rguktvalley/anaconda3/envs/fuel_project/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 1.52188861,  1.11446083,  0.67615842,  0.64959007, -1.27103134,
#         -1.62933005, -0.74203461]])

# %%
prediction2=model_100_epochs.predict(list2)
prediction2
# Out:
# 1/1 [==============================] - 0s 61ms/step
# array([[16.422476]], dtype=float32)

# %%
model_100_epochs.save("models/model_100_epochs.h5")
# Out:
# /home/rguktvalley/anaconda3/envs/fuel_project/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# training with 500 epochs

# %%
model_500_epochs = create_model()

history_500_epochs = model_500_epochs.fit(
    X_train_std,
    Y_train,
    batch_size=100,
    epochs=500
)

model_500_epochs.save("models/model_500_epochs.keras")
# Out:
# Epoch 1/500
# 4/4 [==============================] - 2s 8ms/step - loss: 608.1130 - mean_absolute_error: 23.3618 - mean_squared_error: 608.1130
# Epoch 2/500
# 4/4 [==============================] - 0s 8ms/step - loss: 591.5350 - mean_absolute_error: 23.0029 - mean_squared_error: 591.5350
# Epoch 3/500
# 4/4 [==============================] - 0s 11ms/step - loss: 570.3254 - mean_absolute_error: 22.5254 - mean_squared_error: 570.3254
# Epoch 4/500
# 4/4 [==============================] - 0s 9ms/step - loss: 541.3900 - mean_absolute_error: 21.8448 - mean_squared_error: 541.3900
# Epoch 5/500
# 4/4 [==============================] - 0s 11ms/step - loss: 500.0452 - mean_absolute_error: 20.8454 - mean_squared_error: 500.0451
# Epoch 6/500
# 4/4 [==============================] - 0s 10ms/step - loss: 443.4350 - mean_absolute_error: 19.3393 - mean_squared_error: 443.4350
# Epoch 7/500
# ...

# %%
model_500_epochs.save("models/model_500_epochs.h5")

# %%
rmse=np.sqrt(mean_squared_error(Y_test,prediction))

print('RMSE: ',rmse)

print('R_square:', r2_score(Y_test,prediction))
# Out:
# RMSE:  24.044606854361646
# R_square: -9.607620407930371

# %% [raw]
# predicting a car

# %%
list1=[[4,97,100,5000,14.5,70,3]]
list1=sc.transform(list1)
list1
# Out:
# /home/rguktvalley/anaconda3/envs/fuel_project/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.83920747, -0.90454337, -0.0995444 ,  2.42535646, -0.37958917,
#         -1.62933005,  1.72878276]])

# %% [raw]
# prediction1 = model_500_epochs.predict(list1)
# prediction1

# %%
prediction1
# Out:
# array([[28.102598]], dtype=float32)

# %%
list2=[[8,307,130,3504,12,70,1]]
list2=sc.transform(list2)
list2
# Out:
# /home/rguktvalley/anaconda3/envs/fuel_project/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 1.52188861,  1.11446083,  0.67615842,  0.64959007, -1.27103134,
#         -1.62933005, -0.74203461]])

# %%
prediction2=model_500_epochs.predict(list2)
prediction2
# Out:
# 1/1 [==============================] - 0s 144ms/step
# array([[17.172157]], dtype=float32)

# %% [markdown]
# <h1 style="color:brown">Training with 1000 epochs</h1>

# %%
model_1000_epochs = create_model()

history_1000_epochs = model_1000_epochs.fit(
    X_train_std,
    Y_train,
    batch_size=100,
    epochs=1000
)

model_1000_epochs.save("models/model_1000_epochs.keras")
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 9ms/step - loss: 624.4056 - mean_absolute_error: 23.7279 - mean_squared_error: 624.4056
# Epoch 2/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 614.3314 - mean_absolute_error: 23.5002 - mean_squared_error: 614.3314
# Epoch 3/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 605.2181 - mean_absolute_error: 23.2970 - mean_squared_error: 605.2181
# Epoch 4/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 593.5410 - mean_absolute_error: 23.0367 - mean_squared_error: 593.5410
# Epoch 5/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 576.8594 - mean_absolute_error: 22.6605 - mean_squared_error: 576.8594
# Epoch 6/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 551.2791 - mean_absolute_error: 22.0802 - mean_squared_error: 551.2791
# Epoch 7/1000
# ...

# %%
model_1000_epochs.save("models/model_1000_epochs.h5")
# Out:
# /home/rguktvalley/anaconda3/envs/fuel_project/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
rmse=np.sqrt(mean_squared_error(Y_test,prediction))

print('RMSE: ',rmse)

print('R_square:', r2_score(Y_test,prediction))
# Out:
# RMSE:  24.044606854361646
# R_square: -9.607620407930371

# %% [markdown]
# predicting car fuel efficinecy

# %%
list1=[[4,97,100,5000,14.5,70,3]]
list1=sc.transform(list1)
list1
# Out:
# /home/rguktvalley/anaconda3/envs/fuel_project/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.83920747, -0.90454337, -0.0995444 ,  2.42535646, -0.37958917,
#         -1.62933005,  1.72878276]])

# %%
prediction1 = model_100_epochs.predict(list1)
prediction1
# Out:
# 1/1 [==============================] - 0s 75ms/step
# array([[28.102598]], dtype=float32)

# %%
list2=[[8,307,130,3504,12,70,1]]
list2=sc.transform(list2)
list2
# Out:
# /home/rguktvalley/anaconda3/envs/fuel_project/lib/python3.10/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 1.52188861,  1.11446083,  0.67615842,  0.64959007, -1.27103134,
#         -1.62933005, -0.74203461]])

# %%
prediction2=model_100_epochs.predict(list2)
prediction2
# Out:
# 1/1 [==============================] - 0s 59ms/step
# array([[16.422476]], dtype=float32)

# %%
plt.scatter(Y_test,prediction)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
